# %% [markdown]
# <a href="https://colab.research.google.com/github/rsvr/hello-world/blob/master/sar2sar_denoising_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/malshaV/SAR_DDPM
# %cd SAR_DDPM/
# !python3 setup.py install
# %mkdir weights
# Out:
# Cloning into 'SAR_DDPM'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 56 (delta 5), reused 8 (delta 4), pack-reused 38 (from 1)
# Receiving objects: 100% (56/56), 56.31 KiB | 1.10 MiB/s, done.
# Resolving deltas: 100% (12/12), done.
# /content/SAR_DDPM/SAR_DDPM/SAR_DDPM
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
# ...

# %%
mkdir weights/
# Out:
# mkdir: cannot create directory ‘weights/’: File exists

# %%
# !cd ..
# !pwd
# Out:
# /content/SAR_DDPM/SAR_DDPM/SAR_DDPM

# %%
cd /content/SAR_DDPM/
# Out:
# /content/SAR_DDPM

# %%
mkdir weights

# %%
# !python3 setup.py install
# Out:
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
# ...

# %%
# !git clone https://github.com/openai/guided-diffusion/tree/main/guided_diffusion
# Out:
# Cloning into 'guided_diffusion'...
# fatal: repository 'https://github.com/openai/guided-diffusion/tree/main/guided_diffusion/' not found

# %%
# !python3 setup.py install
# Out:
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
# ...

# %%
ls
# Out:
# build/            deepdespeckling.egg-info/  docs/   img/     Makefile     README.md  test.py
# deepdespeckling/  dist/                      icons/  LICENSE  MANIFEST.in  setup.py   tox.ini

# %%
pwd
# Out:
# '/content/deepdespeckling'

# %%
from deepdespeckling.utils.load_cosar import cos2mat
from deepdespeckling.utils.constants import PATCH_SIZE, STRIDE_SIZE
print("[INFO]:",PATCH_SIZE,STRIDE_SIZE)
from deepdespeckling.sar2sar.sar2sar_denoiser import Sar2SarDenoiser

image='/content/deepdespeckling/img/entire/noisy.png'
print("[INFO]:",image)
denoiser = Sar2SarDenoiser()
import cv2
pixels=cv2.imread(image)
denoised_image = denoiser.denoise_image(pixels,patch_size=PATCH_SIZE, stride_size=STRIDE_SIZE)
cv2.imwrite('/content/output.jpg',denoised_image['denoised'])
# Out:
# [INFO]: 256 254
# [INFO]: /content/deepdespeckling/img/entire/noisy.png
# /usr/local/lib/python3.10/dist-packages/deepdespeckling-0.8-py3.10.egg/deepdespeckling/sar2sar/saved_model/sar2sar.pth
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-928e59f64794> in <cell line: 11>()
#       9 import cv2
#      10 pixels=cv2.imread(image)
# ---> 11 denoised_image = denoiser.denoise_image(pixels,patch_size=PATCH_SIZE, stride_size=STRIDE_SIZE)
#      12 cv2.imwrite('/content/output.jpg',denoised_image['denoised'])
#
# /usr/local/lib/python3.10/dist-packages/deepdespeckling-0.8-py3.10.egg/deepdespeckling/sar2sar/sar2sar_denoiser.py in denoise_image(self, noisy_image, patch_size, stride_size)
#     123             output_image (numpy array): denoised image
#     124         """
# --> 125         noisy_image = np.array(noisy_image).reshape(
# ...
